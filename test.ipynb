# %%
import sys
import os
sys.path.append(os.path.abspath("src"))

import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from destripe import destripe

img = np.array(Image.open("asset/sample.jpeg"))
out = destripe(img, mu1=0.1, mu2=0.001, iterations=1000, verbose=True)
# Out:
# Iteration: 1000 / 1000

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 7))
axes[0].imshow(img, cmap="gray" if img.ndim == 2 else None)
axes[0].set_title("Original")
axes[0].axis("off")
axes[1].imshow(out, cmap="gray" if out.ndim == 2 else None)
axes[1].set_title("Destriped")
axes[1].axis("off")
plt.tight_layout()
plt.show()
